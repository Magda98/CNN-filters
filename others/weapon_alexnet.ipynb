# %%
import torch
from WeaponData_alexnet import WeaponData
from torchvision import models
import torch.nn as nn
from torch.nn import functional as F

# %%
dataset = WeaponData()
# Out:
# ['banknot', 'karta płatnicza', 'nóż', 'pistolet', 'portfel', 'smartphone']

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = models.alexnet(pretrained=True).cuda()
model.fc = nn.Sequential(
               nn.Linear(2048, 1024),
               nn.ReLU(inplace=True),
               nn.Linear(1024,512),
               nn.ReLU(inplace=True),
               nn.Linear(512, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 32),
               nn.ReLU(inplace=True),
               nn.Linear(32, 6)).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters())

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
                data = dataset.trainloader
            else:
                model.eval()
                data = dataset.testloader

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in data:
                inputs = inputs.cuda()
                labels = labels.cuda()

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(data)
            epoch_acc = running_corrects.double() / len(data)

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=50 )
torch.save(model_trained, "./output_data/models/weapon_alexnet")
# Out:
# Epoch 1/50
# ----------
# train loss: 207.5689, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 2/50
# ----------
# train loss: 207.8567, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 3/50
# ----------
# train loss: 208.3216, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 4/50
# ----------
# train loss: 207.9453, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 5/50
# ----------
# train loss: 207.8820, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 6/50
# ----------
# train loss: 208.1369, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 7/50
# ----------
# train loss: 208.2026, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 8/50
# ----------
# train loss: 208.0219, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 9/50
# ----------
# train loss: 208.1778, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 10/50
# ----------
# train loss: 207.8640, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 11/50
# ----------
# train loss: 207.5449, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 12/50
# ----------
# train loss: 208.1436, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 13/50
# ----------
# train loss: 207.7265, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 14/50
# ----------
# train loss: 207.5535, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 15/50
# ----------
# train loss: 208.1686, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 16/50
# ----------
# train loss: 207.9882, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 17/50
# ----------
# train loss: 208.1404, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 18/50
# ----------
# train loss: 207.9342, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 19/50
# ----------
# train loss: 207.6760, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 20/50
# ----------
# train loss: 207.8541, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 21/50
# ----------
# train loss: 208.0581, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 22/50
# ----------
# train loss: 207.5711, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 23/50
# ----------
# train loss: 207.6650, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 24/50
# ----------
# train loss: 207.6997, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 25/50
# ----------
# train loss: 207.8170, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 26/50
# ----------
# train loss: 208.0373, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 27/50
# ----------
# train loss: 207.9766, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 28/50
# ----------
# train loss: 208.2958, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 29/50
# ----------
# train loss: 207.9392, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 30/50
# ----------
# train loss: 207.8601, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 31/50
# ----------
# train loss: 208.2224, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 32/50
# ----------
# train loss: 208.1132, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 33/50
# ----------
# train loss: 207.8632, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 34/50
# ----------
# train loss: 207.6972, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 35/50
# ----------
# train loss: 207.5862, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 36/50
# ----------
# train loss: 208.1803, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 37/50
# ----------
# train loss: 208.0224, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 38/50
# ----------
# train loss: 208.4275, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 39/50
# ----------
# train loss: 207.6092, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 40/50
# ----------
# train loss: 208.1508, acc: 0.0078
# validation loss: 205.3616, acc: 0.0000
# Epoch 41/50
# ----------
# train loss: 207.7062, acc: 0.0059
# validation loss: 205.3617, acc: 0.0000
# Epoch 42/50
# ----------
# train loss: 208.1782, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 43/50
# ----------
# train loss: 207.8700, acc: 0.0020
# validation loss: 205.3616, acc: 0.0000
# Epoch 44/50
# ----------
# train loss: 207.4609, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 45/50
# ----------
# train loss: 207.6608, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 46/50
# ----------
# train loss: 208.4638, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 47/50
# ----------
# train loss: 208.3349, acc: 0.0000
# validation loss: 205.3616, acc: 0.0000
# Epoch 48/50
# ----------
# train loss: 207.7078, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
# Epoch 49/50
# ----------
# train loss: 208.0838, acc: 0.0059
# validation loss: 205.3616, acc: 0.0000
# Epoch 50/50
# ----------
# train loss: 207.4950, acc: 0.0039
# validation loss: 205.3616, acc: 0.0000
