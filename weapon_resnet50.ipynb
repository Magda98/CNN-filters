# %%
import torch
from WeaponData_resnet50 import WeaponData
from torchvision import models
import torch.nn as nn
from torch.nn import functional as F

# %%
dataset = WeaponData()
# Out:
# ['banknot', 'karta płatnicza', 'nóż', 'pistolet', 'portfel', 'smartphone']

# %%
# device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = models.resnet50(pretrained=True).cuda()
model.fc = nn.Sequential(
               nn.Linear(2048, 512),
               nn.ReLU(inplace=True),
               nn.Linear(512, 128),
               nn.ReLU(inplace=True),
               nn.Linear(128, 32),
               nn.ReLU(inplace=True),
               nn.Linear(32, 6)).cuda()

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.fc.parameters())

# %%
def train_model(model, criterion, optimizer, num_epochs=3):
    for epoch in range(num_epochs):
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-' * 10)

        for phase in ['train', 'validation']:
            if phase == 'train':
                model.train()
                data = dataset.trainloader
            else:
                model.eval()
                data = dataset.testloader

            running_loss = 0.0
            running_corrects = 0

            for inputs, labels in data:
                inputs = inputs.cuda()
                labels = labels.cuda()

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                if phase == 'train':
                    optimizer.zero_grad()
                    loss.backward()
                    optimizer.step()

                _, preds = torch.max(outputs, 1)
                running_loss += loss.item() * inputs.size(0)
                running_corrects += torch.sum(preds == labels.data)

            epoch_loss = running_loss / len(data)
            epoch_acc = running_corrects.double() / len(data)

            print('{} loss: {:.4f}, acc: {:.4f}'.format(phase,
                                                        epoch_loss,
                                                        epoch_acc))
    return model

# %%
model_trained = train_model(model, criterion, optimizer, num_epochs=50 )
torch.save(model_trained, "./output_data/models/weapon_resnet50")
# Out:
# Epoch 1/50
# ----------
# train loss: 9.5308, acc: 11.5941
# validation loss: 4.9254, acc: 13.2109
# Epoch 2/50
# ----------
# train loss: 5.5968, acc: 13.0235
# validation loss: 4.2543, acc: 13.4688
# Epoch 3/50
# ----------
# train loss: 5.0369, acc: 13.2941
# validation loss: 4.0436, acc: 13.5547
# Epoch 4/50
# ----------
# train loss: 4.1816, acc: 13.5490
# validation loss: 3.8066, acc: 13.6797
# Epoch 5/50
# ----------
# train loss: 4.3199, acc: 13.5294
# validation loss: 4.4544, acc: 13.3906
# Epoch 6/50
# ----------
# train loss: 3.9713, acc: 13.5902
# validation loss: 3.0214, acc: 13.8906
# Epoch 7/50
# ----------
# train loss: 3.6514, acc: 13.6706
# validation loss: 3.0614, acc: 13.8438
# Epoch 8/50
# ----------
# train loss: 3.4106, acc: 13.8137
# validation loss: 3.1092, acc: 13.8750
# Epoch 9/50
# ----------
# train loss: 3.4350, acc: 13.7843
# validation loss: 2.9357, acc: 13.8984
# Epoch 10/50
# ----------
# train loss: 3.3641, acc: 13.8667
# validation loss: 4.5735, acc: 13.5703
# Epoch 11/50
# ----------
# train loss: 3.0805, acc: 13.9098
# validation loss: 2.8219, acc: 13.9609
# Epoch 12/50
# ----------
# train loss: 2.7803, acc: 14.0098
# validation loss: 3.0012, acc: 13.8984
# Epoch 13/50
# ----------
# train loss: 3.0357, acc: 13.9353
# validation loss: 2.7098, acc: 14.1250
# Epoch 14/50
# ----------
# train loss: 2.5329, acc: 14.0961
# validation loss: 2.9842, acc: 13.9766
# Epoch 15/50
# ----------
# train loss: 2.8604, acc: 13.9765
# validation loss: 3.3528, acc: 13.8516
# Epoch 16/50
# ----------
# train loss: 2.7356, acc: 14.0392
# validation loss: 2.6070, acc: 14.0938
# Epoch 17/50
# ----------
# train loss: 2.6919, acc: 14.0647
# validation loss: 3.2875, acc: 13.9453
# Epoch 18/50
# ----------
# train loss: 2.2091, acc: 14.2235
# validation loss: 3.9495, acc: 13.8438
# Epoch 19/50
# ----------
# train loss: 2.4843, acc: 14.1216
# validation loss: 3.1958, acc: 13.8281
# Epoch 20/50
# ----------
# train loss: 2.1892, acc: 14.2373
# validation loss: 2.6295, acc: 14.0938
# Epoch 21/50
# ----------
# train loss: 2.3322, acc: 14.1667
# validation loss: 2.5768, acc: 14.1562
# Epoch 22/50
# ----------
# train loss: 2.0721, acc: 14.2706
# validation loss: 3.3176, acc: 13.9922
# Epoch 23/50
# ----------
# train loss: 2.1816, acc: 14.2196
# validation loss: 2.9687, acc: 14.0625
# Epoch 24/50
# ----------
# train loss: 1.9761, acc: 14.2824
# validation loss: 3.4284, acc: 13.7969
# Epoch 25/50
# ----------
# train loss: 1.8803, acc: 14.2882
# validation loss: 2.7566, acc: 14.0859
# Epoch 26/50
# ----------
# train loss: 2.0216, acc: 14.2863
# validation loss: 3.4723, acc: 13.9844
# Epoch 27/50
# ----------
# train loss: 1.8879, acc: 14.3059
# validation loss: 3.0179, acc: 13.9922
# Epoch 28/50
# ----------
# train loss: 1.8426, acc: 14.3137
# validation loss: 2.8875, acc: 14.0312
# Epoch 29/50
# ----------
# train loss: 1.7019, acc: 14.4000
# validation loss: 2.9460, acc: 14.0781
# Epoch 30/50
# ----------
# train loss: 1.7084, acc: 14.4196
# validation loss: 2.7014, acc: 14.1172
# Epoch 31/50
# ----------
# train loss: 1.8461, acc: 14.3157
# validation loss: 3.2606, acc: 14.0000
# Epoch 32/50
# ----------
# train loss: 1.6657, acc: 14.3843
# validation loss: 2.9573, acc: 14.0234
# Epoch 33/50
# ----------
# train loss: 1.7149, acc: 14.3843
# validation loss: 3.2187, acc: 14.0234
# Epoch 34/50
# ----------
# train loss: 1.6217, acc: 14.4196
# validation loss: 4.0235, acc: 13.8203
# Epoch 35/50
# ----------
# train loss: 1.5204, acc: 14.4294
# validation loss: 4.0358, acc: 13.9062
# Epoch 36/50
# ----------
# train loss: 1.6317, acc: 14.4216
# validation loss: 4.0321, acc: 13.7656
# Epoch 37/50
# ----------
# train loss: 1.4713, acc: 14.4686
# validation loss: 4.2034, acc: 13.7031
# Epoch 38/50
# ----------
# train loss: 1.6164, acc: 14.4020
# validation loss: 2.8371, acc: 14.0156
# Epoch 39/50
# ----------
# train loss: 1.6154, acc: 14.4235
# validation loss: 2.5991, acc: 14.1328
# Epoch 40/50
# ----------
# train loss: 1.5971, acc: 14.4627
# validation loss: 3.3593, acc: 13.9453
# Epoch 41/50
# ----------
# train loss: 1.2138, acc: 14.5863
# validation loss: 2.8035, acc: 14.0859
# Epoch 42/50
# ----------
# train loss: 1.4885, acc: 14.4686
# validation loss: 2.7358, acc: 14.2109
# Epoch 43/50
# ----------
# train loss: 1.4310, acc: 14.5000
# validation loss: 3.4335, acc: 14.0000
# Epoch 44/50
# ----------
# train loss: 1.2133, acc: 14.5510
# validation loss: 3.2735, acc: 14.1094
# Epoch 45/50
# ----------
# train loss: 1.3292, acc: 14.5549
# validation loss: 3.8262, acc: 13.9453
# Epoch 46/50
# ----------
# train loss: 1.2847, acc: 14.5333
# validation loss: 2.5729, acc: 14.2031
# Epoch 47/50
# ----------
# train loss: 1.3362, acc: 14.5392
# validation loss: 3.9803, acc: 14.0078
# Epoch 48/50
# ----------
# train loss: 1.2294, acc: 14.5706
# validation loss: 3.0857, acc: 14.1328
# Epoch 49/50
# ----------
# train loss: 1.4342, acc: 14.5451
# validation loss: 3.2176, acc: 14.0625
# Epoch 50/50
# ----------
# train loss: 1.1819, acc: 14.5235
# validation loss: 3.0965, acc: 14.0781
